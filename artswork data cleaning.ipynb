# %%
import csv

# %%
dataset = list(csv.reader(open("artworks.csv",encoding="utf-8")))

# %%
header = dataset[0]
dataset = dataset[1:]

# %%
for i in dataset:
    natioanlity = i[2]
    natioanlity = natioanlity.replace("(","").replace(")","")
    i[2] = nationality
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
#       2 natioanlity = i[2]
#       3 natioanlity = natioanlity.replace("(","").replace(")","")
# ----> 4 i[2] = nationality
#
# NameError: name 'nationality' is not defined

# %%
dataset[0]

# %%
"(American)".replace("(","")

# %%
for i in dataset:
    nationality = i[2]
    nationality = nationality.replace("(","").replace(")","")
    i[2] = nationality

# %%
dataset[2]

# %% [markdown]
# for i in dataset:
#     print(i)

# %%
for i in dataset:
    gender = i[5]
    gender = gender.replace("(","").replace(")","")
    i[5] = gender
    if gender == "":
        gender = "unknown gender"
    i[5] = gender

# %%
for i in dataset:
    print(i[5])
# Out:
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# unknown gender
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Female
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# unknown gender
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# Female
# Male
# Male
# Male
# Male
# ...

# %%
def clean_convert(date):
    if date != "":
        date = date.replace("-","")
        date = int(date)
    return date

# %%
for i in dataset[:10]:
    print(i[3],i[4])
# Out:
# -1947 -2013
# -1916 -2007
# -1870 -1943
# -1861 -1944
# -1857 -1927
# -1919 -2013
# -1857 -1927
# -1928 -1984
# -1964
# -1882 -1953

# %%
for i in dataset[:10]:
    birthdate = i[3]
    deathdate = i[4]
    birthdate = birthdate.replace("-","")
    deathdate = deathdate.replace("-","")
    i[3] = birthdate
    i[4] = deathdate

# %%
datats
# Out:
# 1
# 8
# 8
# 2

# %%
int("23")
# Out:
# 23

# %%
clean_convert("-123")
# Out:
# 123

# %%
for i in dataset[:10]:
    birthdate = i[3]
    deathdate = i[4]
    birthdate = clean_convert(birthdate)
    deathdate = clean_convert(deathdate)
    i[3] = birthdate
    i[4] = deathdate

# %%
for i in dataset:
    nationality = i[2]
    nationality = nationality.replace("(","").replace(")","")
    i[2] = nationality

# %%
for i in dataset:
    print(i[2])
# Out:
# American
# Spanish
# French
# French
# French
# American
# French
# American
# South African
# Canadian
# French
# American
# Czech
# American
# American
# American
# Belgian
# American
# American
# Spanish
# American
# Russian
# American
# French
# French
# French
# British
# French
# French
# German
# Belgian
#
# American
# American
# American
# Swiss
#
# American
# American
# Polish
# British
# American
# American
# Belgian
# American
# Japanese
# American
# American
# Spanish
# American
# French
# American
# American
# American
# American
# French
# American
# American
# French
# American
# American
# Portuguese
# American
# American
# Austrian
# Swiss
# German
# American
# American
# French
# British
# American
# French
# American
# British
# German
# French
# French
# Australian
# American
# French
# Spanish
# German
# American
# American
# French
# American
# American
# American
# French
# Italian
# American
# American
# American
# American
# American
# French
# American
# ...

# %%
for i in dataset:
    date1 = i[6]
    date1 = date1.replace("--","-")
    i[6] = date1

# %%
for i in dataset:
    date = i[6]
    date = date.replace("c","").replace(".","")
    if date.startswith("-"):
        date = date.replace("-","")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [111], in <cell line: 1>()
#       1 for i in dataset:
#       2     date = i[6]
# ----> 3     date = date.replace("c","").replace(".","")
#       4     if date.startswith("-"):
#       5         date = date.replace("-","")
#
# AttributeError: 'bool' object has no attribute 'replace'

# %%
for i in dataset:
    print(i[6])
# Out:
# 1986
# 1978
# 1889-1911
# 1927-1940
# 1903
# 1957
# 1924
# 1978-1983
# 2001
# -1941
# 1949-1950
# 1963
# 1908-1911
# -1934
# 1997
# (1931-1933)
# 1972
# 1967
# 1923-1924
# 1979
# 1925-1927
# 1929
# 1972
# 1974
# 1957
# 1920-1930
# 1974
# 1915
# 1912
# 1988-1990
# 1925
# -1925
# 1980
# 1964
# 1968
# 1969
# 1934
# 1953
# 1971
# 1988
# 1818
# 2002
# 1926
# 1969
# 1914
# 1979
# 1968
# 1979
# 1966
# 1904
# 1949
# 1981
# 1970
# 1969
# 1972
# 1923-1925
# 1967
# 1932
# 1928
# 1965
# 2003
# 1971-1974
# 1983
# 1930
# 1946
# 1984
# 2006
# -1885
# 1942
# 1913
# 2015
# 1987
# 1947-1949
# 1965
# 1818
# 1961
# 1925
# 1916-1932
# 1962
# 1944
# 1930
# 1991
# 1991-1994
# 2008
# 1975
# 1893
# 1966
# 1968-1969
# 1964-1968
# 1928-1939
# 1969
# 1942
# 1980
# 1955
# 1930
# -1955-1960
# 1922
# 1934
# 1903
# 2008
# 1962
# 1944
# 1914-1918
# -2003
# 2012
# 1965
# 1865
# 1976
# 1902
# 2003
# 2010
# 1944
# 1963
# 1875
# 1948
# 1990
# 1913
# 1958
# 1921
# 1970
# 1950
# 2004
# 1926
# 1973
# 1915
# 2003
# 1973
# ...

# %%
def clean(data):
    data = data.replace("_"," ")
    return data

# %%
clean("unknown_gender")
# Out:
# 'unknown gender'
